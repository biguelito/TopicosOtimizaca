# %%
import pulp
import pandas as pd

# %%
def gerar_grade_horaria_por_turma(tabela, instancia, turma_escolhida):
    horarios = instancia["horarios"]
    horarios_legenda = instancia["horarios_legenda"]
    dias = ["Segunda", "Terça", "Quarta", "Quinta", "Sexta"]

    codigos_horario = sorted(
        {h.split("_")[1] for h in horarios},
        key=lambda x: (x[0], int(x[1]))
    )
    eixo_y = [horarios_legenda[codigo] for codigo in codigos_horario]
    grade = pd.DataFrame("", index=eixo_y, columns=dias)
    aulas_turma = tabela[tabela["turma"] == turma_escolhida]

    for _, aula in aulas_turma.iterrows():
        dia, codigo = aula["horario"].split("_")
        horario_legivel = horarios_legenda[codigo]

        conteudo = (
            f"{aula['disciplina']} - {aula['professor']} - {aula['sala']}"
        )

        grade.loc[horario_legivel, dia] = conteudo

    return grade

def exportar_grades_para_excel(tabela, instancia, caminho_arquivo_excel="grade_horaria_escola.xlsx", pasta=None):
    turmas = instancia["turmas"]

    with pd.ExcelWriter(f"{pasta}/{caminho_arquivo_excel}", engine="openpyxl") as writer:
        for turma in turmas:
            grade = gerar_grade_horaria_por_turma(tabela, instancia, turma)
            nome_aba = f"Turma_{turma}"[:31]
            grade.to_excel(writer, sheet_name=nome_aba)

    print(f"Arquivo Excel gerado: {caminho_arquivo_excel}")

# %%
def montar_instancia(turmas_por_3_ano : int, turmas_por_2_ano : int, total_salas : int):
    disciplinas_obrigatorias = ["Matematica", "Fisica", "Quimica", "Portugues", "Lingua Inglesa", "Filosofia", "Sociologia", "Geografia", "Historia", "Educacao Fisica", "Biologia", "Arte"]
    disciplinas_itinerario_formativo = ["Senac", "CESAR", "Inovativa"]
    disciplinas_complementares = ["Cultura digital", "Estudo orientado"]
    professores = [
                    "prof1", "prof2", "prof3", "prof4", "prof5", "prof6", "prof7", "prof8", "prof9", "prof10", "prof11", "prof12", 
                    "prof_int1",
                    "prof_ext1", "prof_ext2",
                    "prof_comp1", "prof_comp2"
                    ]

    horarios = ["Segunda_M1", "Segunda_M2", "Segunda_M3", "Segunda_M4", "Segunda_T1", "Segunda_T2", "Segunda_T3", "Segunda_T4", 
                "Terça_M1", "Terça_M2", "Terça_M3", "Terça_M4", "Terça_T1", "Terça_T2", "Terça_T3", "Terça_T4",
                "Quarta_M1", "Quarta_M2", "Quarta_M3", "Quarta_M4", "Quarta_T1", "Quarta_T2", "Quarta_T3", "Quarta_T4",
                "Quinta_M1", "Quinta_M2", "Quinta_M3", "Quinta_M4", "Quinta_T1", "Quinta_T2", "Quinta_T3", "Quinta_T4",
                "Sexta_M1", "Sexta_M2", "Sexta_M3", "Sexta_M4", "Sexta_T1", "Sexta_T2", "Sexta_T3", "Sexta_T4"
                ]
    horarios_legenda = {"M1": "8 às 9", "M2": "9 às 10", "M3": "10 às 11", "M4": "11 às 12", 
                        "T1": "13 às 14", "T2": "14 às 15", "T3": "15 às 16", "T4": "16 às 17"}

    professor_pode_lecionar = {
        ("prof1", "Matematica"): 1,
        ("prof2", "Fisica"): 1,
        ("prof3", "Quimica"): 1,
        ("prof4", "Portugues"): 1,
        ("prof5", "Lingua Inglesa"): 1,
        ("prof6", "Filosofia"): 1,
        ("prof7", "Sociologia"): 1,
        ("prof8", "Geografia"): 1,
        ("prof9", "Historia"): 1,
        ("prof10", "Educacao Fisica"): 1,
        ("prof11", "Biologia"): 1,
        ("prof12", "Arte"): 1,
        ("prof_int1", "Inovativa"): 1,
        ("prof_ext1", "Senac"): 1,
        ("prof_ext2", "CESAR"): 1,
        ("prof_comp1", "Cultura digital"): 1,
        ("prof_comp2", "Estudo orientado"): 1,
    }

    # disponibilidade = {(p, h): 1 for p in professores for h in horarios}
    disponibilidade = {}
        
    for professor in professores:
        for horario in horarios:

            if professor.startswith("prof") and professor[4:].isdigit():
                disponibilidade[(professor, horario)] = 1

            elif professor.startswith("prof_int") or professor.startswith("prof_ext"):
                if "_T" in horario:
                    disponibilidade[(professor, horario)] = 1
                else:
                    disponibilidade[(professor, horario)] = 0

            elif professor.startswith("prof_comp"):
                if "_M" in horario:
                    disponibilidade[(professor, horario)] = 1
                else:
                    disponibilidade[(professor, horario)] = 0

    salas = []
    for s in range(1, total_salas+1):
        salas += [f"Sala_{s}"]

    turmas = []
    ano_turma = {}
    turma_sala = {}

    turmas_por_1_ano = total_salas - turmas_por_2_ano - turmas_por_3_ano
    turma_sala_pos = 0
    for numero_ano_turma, quant_turma in enumerate([turmas_por_1_ano, turmas_por_2_ano, turmas_por_3_ano]):
        for t in range(quant_turma):
            cod_turma = f"{numero_ano_turma+1}{chr(65+t)}"
            turmas += [cod_turma]
            ano_turma[cod_turma] = numero_ano_turma+1
            turma_sala[cod_turma] = salas[turma_sala_pos]
            turma_sala_pos += 1

    quantidade_aulas = {}
    for turma in turmas:
        quantidade_aulas[(turma, "Arte")] = 1
        quantidade_aulas[(turma, "Biologia")] = 2
        quantidade_aulas[(turma, "Educacao Fisica")] = 1
        quantidade_aulas[(turma, "Filosofia")] = 1
        quantidade_aulas[(turma, "Fisica")] = 2
        quantidade_aulas[(turma, "Geografia")] = 2
        quantidade_aulas[(turma, "Historia")] = 2
        quantidade_aulas[(turma, "Lingua Inglesa")] = 2
        quantidade_aulas[(turma, "Portugues")] = 4
        quantidade_aulas[(turma, "Matematica")] = 4
        quantidade_aulas[(turma, "Quimica")] = 2
        quantidade_aulas[(turma, "Sociologia")] = 1

        if (ano_turma[turma] == 3):
            quantidade_aulas[(turma, "Matematica")] = 5
            quantidade_aulas[(turma, "Portugues")] = 5

    return {
        "turmas": turmas,
        "ano_da_turma": ano_turma,
        "disciplinas_obrigatorias": disciplinas_obrigatorias,
        "professores": professores,
        "horarios": horarios,
        "horarios_legenda": horarios_legenda,
        "salas": salas,
        "professor_pode_lecionar": professor_pode_lecionar,
        "professor_disponivel_no_horario": disponibilidade,
        "quantidade_aulas": quantidade_aulas,
        "disciplinas_complementares": disciplinas_complementares,
        "disciplinas_itinerario_formativo": disciplinas_itinerario_formativo,
        "turma_sala": turma_sala
    }

# %%
def construir_e_resolver_modelo(instancia, limite_tempo=120):
    # Variaveis
    turmas = instancia["turmas"]
    ano_da_turma = instancia["ano_da_turma"]
    turma_sala = instancia["turma_sala"]
    professores = instancia["professores"]
    horarios = instancia["horarios"]

    disciplinas_obrigatorias = instancia["disciplinas_obrigatorias"]
    disciplinas_complementares = set(instancia.get("disciplinas_complementares", []))
    disciplinas_itinerario_formativo = set(instancia.get("disciplinas_itinerario_formativo", []))
    disciplinas = (
        set(disciplinas_obrigatorias)
        | set(disciplinas_itinerario_formativo)
        | set(disciplinas_complementares)
    )

    # Algumas limitacoes
    professor_pode_lecionar = instancia["professor_pode_lecionar"]
    professor_disponivel_no_horario = instancia["professor_disponivel_no_horario"]
    quantidade_aulas = instancia["quantidade_aulas"]

    atribuicoes_fixas = set(instancia.get("atribuicoes_fixas", []))

    def contar_fixas(turma, conjunto_disciplinas):
        return sum(
            1 for (t, d, _, _) in atribuicoes_fixas
            if t == turma and d in conjunto_disciplinas
        )

    #  VARIÁVEIS DE DECISÃO
    #  x[turma, disciplina, professor, horario] = 1 se a aula ocorre

    # Objetivo zero (somente factibilidade)
    problema = pulp.LpProblem("Alocacao_Aulas_Escolar")
    problema += 0, "Objetivo_Nulo"

    variavel_alocacao = {}

    for turma in turmas:
        # sala = turma_sala[turma]
        for disciplina in disciplinas:
            for professor in professores:
                for horario in horarios:

                    if professor_pode_lecionar.get((professor, disciplina), 0) == 0:
                        continue

                    if professor_disponivel_no_horario.get((professor, horario), 0) == 0:
                        continue

                    variavel_alocacao[(turma, disciplina, professor, horario)] = (
                        pulp.LpVariable(
                            f"alocar_{turma}_{disciplina}_{professor}_{horario}",
                            cat="Binary"
                        )
                    )

    for (turma, disciplina, professor, horario) in atribuicoes_fixas:
        chave = (turma, disciplina, professor, horario)
        if chave not in variavel_alocacao:
            raise ValueError(f"Atribuição fixa inválida: {chave}")

        problema += (
            variavel_alocacao[chave] == 1,
            f"fixa_{turma}_{disciplina}_{professor}_{horario}"
        )


    #  RESTRIÇÃO 1 - QUANTIDADE DE AULAS DE DISCIPLINAS OBRIGATORIAS 
    for turma in turmas:
        for disciplina in disciplinas_obrigatorias:

            problema += (
                pulp.lpSum(
                    variavel_alocacao.get((turma, disciplina, professor, horario), 0)
                    for professor in professores
                    for horario in horarios
                ) == quantidade_aulas[(turma, disciplina)],
                f"cobertura_{turma}_{disciplina}"
            )

    #  RESTRIÇÃO 2 - UMA AULA POR TURMA POR HORÁRIO 
    for turma in turmas:
        for horario in horarios:

            problema += (
                pulp.lpSum(
                    variavel_alocacao.get((turma, disciplina, professor, horario), 0)
                    for disciplina in disciplinas
                    for professor in professores
                ) <= 1,
                f"uma_aula_por_turma_por_horario_{turma}_{horario}"
            )

    #  RESTRIÇÃO 3 - UM PROFESSOR POR HORÁRIO
    for professor in professores:
        for horario in horarios:

            problema += (
                pulp.lpSum(
                    variavel_alocacao.get((turma, disciplina, professor, horario), 0)
                    for turma in turmas
                    for disciplina in disciplinas
                ) <= 1,
                f"um_professor_por_horario_{professor}_{horario}"
            )

    # RESTRIÇÕES 4 — REGRAS POR ANO DA TURMA

    # 1 ANO - 
    turmas_ano1 = [t for t in turmas if ano_da_turma[t] == 1]
    itinerarios_usados = {
        d for (t, d, _, _) in atribuicoes_fixas
        if t in turmas_ano1 and d in disciplinas_itinerario_formativo
    }
    turmas_ano1_com_fixa = {
        t for (t, d, _, _) in atribuicoes_fixas
        if t in turmas_ano1 and d in disciplinas_itinerario_formativo
    }
    turmas_sem_fixa = set(turmas_ano1) - turmas_ano1_com_fixa

    # Turmas COM itinerário fixo proíbe qualquer outro itinerário
    for turma in turmas_ano1_com_fixa:
        disciplina_fixa = next(
            d for (t, d, _, _) in atribuicoes_fixas
            if t == turma and d in disciplinas_itinerario_formativo
        )

        for d in disciplinas_itinerario_formativo:
            if d != disciplina_fixa:
                for professor in professores:
                    for horario in horarios:
                        chave = (turma, d, professor, horario)
                        if chave in variavel_alocacao:
                            problema += (
                                variavel_alocacao[chave] == 0,
                                f"bloqueio_itinerario_{turma}_{d}_{horario}"
                            )

    # Turmas SEM itinerário fixo só podem usar itinerários ainda não usados
    for turma in turmas_sem_fixa:
        for d in itinerarios_usados:
            for professor in professores:
                for horario in horarios:
                    chave = (turma, d, professor, horario)
                    if chave in variavel_alocacao:
                        problema += (
                            variavel_alocacao[chave] == 0,
                            f"bloqueio_itinerario_usado_{turma}_{d}_{horario}"
                        )

    # Turmas do 1º ano exatamente 2 aulas de UM único itinerário
    for turma in turmas_ano1:
        problema += (
            pulp.lpSum(
                variavel_alocacao.get((turma, d, professor, horario), 0)
                for d in disciplinas_itinerario_formativo
                for professor in professores
                for horario in horarios
            ) == 2,
            f"ano1_exatamente_duas_aulas_itinerario_{turma}"
        )

    # 2 ANO - 
    turmas_ano2 = [t for t in turmas if ano_da_turma[t] == 2]
    itinerarios_usados_ano2 = {
        d for (t, d, _, _) in atribuicoes_fixas
        if t in turmas_ano2 and d in disciplinas_itinerario_formativo
    }
    turmas_ano2_com_fixa = {
        t for (t, d, _, _) in atribuicoes_fixas
        if t in turmas_ano2 and d in disciplinas_itinerario_formativo
    }
    turmas_ano2_sem_fixa = set(turmas_ano2) - turmas_ano2_com_fixa

    # Turmas COM itinerário fixo. Proíbe qualquer outro itinerário
    for turma in turmas_ano2_com_fixa:
        disciplina_fixa = next(
            d for (t, d, _, _) in atribuicoes_fixas
            if t == turma and d in disciplinas_itinerario_formativo
        )

        for d in disciplinas_itinerario_formativo:
            if d != disciplina_fixa:
                for professor in professores:
                    for horario in horarios:
                        chave = (turma, d, professor, horario)
                        if chave in variavel_alocacao:
                            problema += (
                                variavel_alocacao[chave] == 0,
                                f"ano2_bloqueio_itinerario_{turma}_{d}_{horario}"
                            )

        # exatamente 2 aulas do itinerário fixo
        problema += (
            pulp.lpSum(
                variavel_alocacao.get((turma, disciplina_fixa, professor, horario), 0)
                for professor in professores
                for horario in horarios
            ) == 2,
            f"ano2_duas_aulas_itinerario_fixo_{turma}"
        )

    # Turmas SEM itinerário fixo. Itinerários não usados OU complementares
    for turma in turmas_ano2_sem_fixa:

        # Bloqueia itinerários já usados
        for d in itinerarios_usados_ano2:
            for professor in professores:
                for horario in horarios:
                    chave = (turma, d, professor, horario)
                    if chave in variavel_alocacao:
                        problema += (
                            variavel_alocacao[chave] == 0,
                            f"ano2_bloqueio_itinerario_usado_{turma}_{d}_{horario}"
                        )

        # Total de aulas (itinerário + complementares) = 2
        problema += (
            pulp.lpSum(
                variavel_alocacao.get((turma, d, p, h), 0)
                for d in (disciplinas_itinerario_formativo | disciplinas_complementares)
                for p in professores
                for h in horarios
            ) == 2,
            f"ano2_total_duas_aulas_{turma}"
        )

        # No máximo 1 itinerário (se escolher itinerário, as 2 aulas são dele)
        problema += (
            pulp.lpSum(
                variavel_alocacao.get((turma, d, p, h), 0)
                for d in disciplinas_itinerario_formativo
                for p in professores
                for h in horarios
            ) <= 2,
            f"ano2_max_duas_itinerario_{turma}"
        )

        # Cada disciplina complementar no máximo 1 vez
        for d in disciplinas_complementares:
            problema += (
                pulp.lpSum(
                    variavel_alocacao.get((turma, d, p, h), 0)
                    for p in professores
                    for h in horarios
                ) <= 1,
                f"ano2_complementar_unica_{turma}_{d}"
            )

    # 3 ANO - exatamente 1 aula de cada disciplina complementar
    for turma in turmas:
        if ano_da_turma[turma] == 3:
            for disciplina in disciplinas_complementares:
                problema += (
                    pulp.lpSum(
                        variavel_alocacao.get((turma, disciplina, professor, horario), 0)
                        for professor in professores
                        for horario in horarios
                    ) == 1,
                    f"ano3_complementar_{turma}_{disciplina}"
                )

    #  SOLVER
    solver = pulp.PULP_CBC_CMD(msg=True, timeLimit=limite_tempo, threads=2)
    status = problema.solve(solver)

    print("\nSTATUS DO SOLVER:", pulp.LpStatus[problema.status])

    atribuicoes = []

    # Atribuições fixas
    for (turma, disc_ext, professor, horario) in atribuicoes_fixas:
        atribuicoes.append({
            "turma": turma,
            "disciplina": disc_ext,
            "professor": professor,
            "horario": horario,
            "sala": turma_sala[turma],
            "fixa": True
        })

    # Atribuições decididas pelo modelo
    for chave, var in variavel_alocacao.items():
        if pulp.value(var) is not None and pulp.value(var) > 0.5:
            turma, disc_ext, professor, horario = chave
            atribuicoes.append({
                "turma": turma,
                "disciplina": disc_ext,
                "professor": professor,
                "horario": horario,
                "sala": turma_sala[turma],
                "fixa": False
            })

    df = pd.DataFrame(atribuicoes)
    if not df.empty:
        df = df.sort_values(["horario", "turma", "disciplina"]).reset_index(drop=True)

    return problema, df

# %%
# x[turma, disciplina, professor, horario] = 1
atribuicoes_fixas = {
    ("1A", "Senac", "prof_ext1", "Quarta_T1"),
    ("1A", "Senac", "prof_ext1", "Quinta_T1"),
    ("1B", "CESAR", "prof_ext2", "Segunda_T1"),
    ("1B", "CESAR", "prof_ext2", "Quarta_T1"),
    ("2A", "CESAR", "prof_ext2", "Terça_T1"),
    ("2A", "CESAR", "prof_ext2", "Quinta_T1"),
}
instancia = montar_instancia(turmas_por_3_ano=3, turmas_por_2_ano=3, total_salas=9)
instancia["atribuicoes_fixas"] = atribuicoes_fixas
instancia
# Out:
# {'turmas': ['1A', '1B', '1C', '2A', '2B', '2C', '3A', '3B', '3C'],
#  'ano_da_turma': {'1A': 1,
#   '1B': 1,
#   '1C': 1,
#   '2A': 2,
#   '2B': 2,
#   '2C': 2,
#   '3A': 3,
#   '3B': 3,
#   '3C': 3},
#  'disciplinas_obrigatorias': ['Matematica',
#   'Fisica',
#   'Quimica',
#   'Portugues',
#   'Lingua Inglesa',
#   'Filosofia',
#   'Sociologia',
#   'Geografia',
#   'Historia',
#   'Educacao Fisica',
#   'Biologia',
#   'Arte'],
#  'professores': ['prof1',
#   'prof2',
#   'prof3',
#   'prof4',
#   'prof5',
#   'prof6',
#   'prof7',
#   'prof8',
#   'prof9',
#   'prof10',
#   'prof11',
#   'prof12',
#   'prof_int1',
#   'prof_ext1',
#   'prof_ext2',
#   'prof_comp1',
#   'prof_comp2'],
#  'horarios': ['Segunda_M1',
#   'Segunda_M2',
#   'Segunda_M3',
#   'Segunda_M4',
#   'Segunda_T1',
#   'Segunda_T2',
#   'Segunda_T3',
#   'Segunda_T4',
#   'Terça_M1',
#   'Terça_M2',
#   'Terça_M3',
#   'Terça_M4',
#   'Terça_T1',
#   'Terça_T2',
#   'Terça_T3',
#   'Terça_T4',
#   'Quarta_M1',
#   'Quarta_M2',
#   'Quarta_M3',
#   'Quarta_M4',
#   'Quarta_T1',
#   'Quarta_T2',
#   'Quarta_T3',
#   'Quarta_T4',
#   'Quinta_M1',
#   'Quinta_M2',
#   'Quinta_M3',
#   'Quinta_M4',
#   'Quinta_T1',
#   'Quinta_T2',
#   'Quinta_T3',
#   'Quinta_T4',
#   'Sexta_M1',
#   'Sexta_M2',
#   'Sexta_M3',
#   'Sexta_M4',
#   'Sexta_T1',
#   'Sexta_T2',
#   'Sexta_T3',
#   'Sexta_T4'],
#  'horarios_legenda': {'M1': '8 às 9',
#   'M2': '9 às 10',
#   'M3': '10 às 11',
#   'M4': '11 às 12',
#   'T1': '13 às 14',
#   'T2': '14 às 15',
#   'T3': '15 às 16',
#   'T4': '16 às 17'},
#  'salas': ['Sala_1',
#   'Sala_2',
#   'Sala_3',
#   'Sala_4',
#   'Sala_5',
#   'Sala_6',
#   'Sala_7',
#   'Sala_8',
#   'Sala_9'],
#  'professor_pode_lecionar': {('prof1', 'Matematica'): 1,
#   ('prof2', 'Fisica'): 1,
#   ('prof3', 'Quimica'): 1,
#   ('prof4', 'Portugues'): 1,
#   ('prof5', 'Lingua Inglesa'): 1,
#   ('prof6', 'Filosofia'): 1,
#   ('prof7', 'Sociologia'): 1,
#   ('prof8', 'Geografia'): 1,
#   ('prof9', 'Historia'): 1,
#   ('prof10', 'Educacao Fisica'): 1,
#   ('prof11', 'Biologia'): 1,
#   ('prof12', 'Arte'): 1,
#   ('prof_int1', 'Inovativa'): 1,
#   ('prof_ext1', 'Senac'): 1,
#   ('prof_ext2', 'CESAR'): 1,
#   ('prof_comp1', 'Cultura digital'): 1,
#   ('prof_comp2', 'Estudo orientado'): 1},
#  'professor_disponivel_no_horario': {('prof1', 'Segunda_M1'): 1,
#   ('prof1', 'Segunda_M2'): 1,
#   ('prof1', 'Segunda_M3'): 1,
#   ('prof1', 'Segunda_M4'): 1,
#   ('prof1', 'Segunda_T1'): 1,
#   ('prof1', 'Segunda_T2'): 1,
#   ('prof1', 'Segunda_T3'): 1,
#   ('prof1', 'Segunda_T4'): 1,
#   ('prof1', 'Terça_M1'): 1,
#   ('prof1', 'Terça_M2'): 1,
#   ('prof1', 'Terça_M3'): 1,
#   ('prof1', 'Terça_M4'): 1,
#   ('prof1', 'Terça_T1'): 1,
#   ('prof1', 'Terça_T2'): 1,
#   ('prof1', 'Terça_T3'): 1,
#   ('prof1', 'Terça_T4'): 1,
#   ('prof1', 'Quarta_M1'): 1,
#   ('prof1', 'Quarta_M2'): 1,
#   ('prof1', 'Quarta_M3'): 1,
#   ('prof1', 'Quarta_M4'): 1,
#   ('prof1', 'Quarta_T1'): 1,
#   ('prof1', 'Quarta_T2'): 1,
#   ('prof1', 'Quarta_T3'): 1,
#   ('prof1', 'Quarta_T4'): 1,
#   ('prof1', 'Quinta_M1'): 1,
#   ('prof1', 'Quinta_M2'): 1,
#   ('prof1', 'Quinta_M3'): 1,
#   ('prof1', 'Quinta_M4'): 1,
#   ('prof1', 'Quinta_T1'): 1,
#   ('prof1', 'Quinta_T2'): 1,
#   ('prof1', 'Quinta_T3'): 1,
#   ('prof1', 'Quinta_T4'): 1,
#   ('prof1', 'Sexta_M1'): 1,
#   ('prof1', 'Sexta_M2'): 1,
#   ('prof1', 'Sexta_M3'): 1,
#   ('prof1', 'Sexta_M4'): 1,
#   ('prof1', 'Sexta_T1'): 1,
#   ('prof1', 'Sexta_T2'): 1,
#   ('prof1', 'Sexta_T3'): 1,
#   ('prof1', 'Sexta_T4'): 1,
#   ('prof2', 'Segunda_M1'): 1,
#   ('prof2', 'Segunda_M2'): 1,
#   ('prof2', 'Segunda_M3'): 1,
#   ('prof2', 'Segunda_M4'): 1,
#   ('prof2', 'Segunda_T1'): 1,
#   ('prof2', 'Segunda_T2'): 1,
#   ('prof2', 'Segunda_T3'): 1,
#   ('prof2', 'Segunda_T4'): 1,
#   ('prof2', 'Terça_M1'): 1,
#   ('prof2', 'Terça_M2'): 1,
#   ('prof2', 'Terça_M3'): 1,
#   ('prof2', 'Terça_M4'): 1,
#   ('prof2', 'Terça_T1'): 1,
#   ('prof2', 'Terça_T2'): 1,
#   ('prof2', 'Terça_T3'): 1,
#   ('prof2', 'Terça_T4'): 1,
#   ('prof2', 'Quarta_M1'): 1,
#   ('prof2', 'Quarta_M2'): 1,
#   ('prof2', 'Quarta_M3'): 1,
#   ('prof2', 'Quarta_M4'): 1,
#   ('prof2', 'Quarta_T1'): 1,
#   ('prof2', 'Quarta_T2'): 1,
#   ('prof2', 'Quarta_T3'): 1,
#   ('prof2', 'Quarta_T4'): 1,
#   ('prof2', 'Quinta_M1'): 1,
#   ('prof2', 'Quinta_M2'): 1,
#   ('prof2', 'Quinta_M3'): 1,
#   ('prof2', 'Quinta_M4'): 1,
#   ('prof2', 'Quinta_T1'): 1,
#   ('prof2', 'Quinta_T2'): 1,
#   ('prof2', 'Quinta_T3'): 1,
#   ('prof2', 'Quinta_T4'): 1,
#   ('prof2', 'Sexta_M1'): 1,
#   ('prof2', 'Sexta_M2'): 1,
#   ('prof2', 'Sexta_M3'): 1,
#   ('prof2', 'Sexta_M4'): 1,
#   ('prof2', 'Sexta_T1'): 1,
#   ('prof2', 'Sexta_T2'): 1,
#   ('prof2', 'Sexta_T3'): 1,
#   ('prof2', 'Sexta_T4'): 1,
#   ('prof3', 'Segunda_M1'): 1,
#   ('prof3', 'Segunda_M2'): 1,
#   ('prof3', 'Segunda_M3'): 1,
#   ('prof3', 'Segunda_M4'): 1,
#   ('prof3', 'Segunda_T1'): 1,
#   ('prof3', 'Segunda_T2'): 1,
#   ('prof3', 'Segunda_T3'): 1,
#   ('prof3', 'Segunda_T4'): 1,
#   ('prof3', 'Terça_M1'): 1,
#   ('prof3', 'Terça_M2'): 1,
#   ('prof3', 'Terça_M3'): 1,
#   ('prof3', 'Terça_M4'): 1,
#   ('prof3', 'Terça_T1'): 1,
#   ('prof3', 'Terça_T2'): 1,
#   ('prof3', 'Terça_T3'): 1,
#   ('prof3', 'Terça_T4'): 1,
#   ('prof3', 'Quarta_M1'): 1,
#   ('prof3', 'Quarta_M2'): 1,
#   ('prof3', 'Quarta_M3'): 1,
#   ('prof3', 'Quarta_M4'): 1,
#   ('prof3', 'Quarta_T1'): 1,
#   ('prof3', 'Quarta_T2'): 1,
#   ('prof3', 'Quarta_T3'): 1,
#   ('prof3', 'Quarta_T4'): 1,
#   ('prof3', 'Quinta_M1'): 1,
#   ('prof3', 'Quinta_M2'): 1,
#   ('prof3', 'Quinta_M3'): 1,
#   ('prof3', 'Quinta_M4'): 1,
#   ('prof3', 'Quinta_T1'): 1,
#   ('prof3', 'Quinta_T2'): 1,
#   ('prof3', 'Quinta_T3'): 1,
#   ('prof3', 'Quinta_T4'): 1,
#   ('prof3', 'Sexta_M1'): 1,
#   ('prof3', 'Sexta_M2'): 1,
#   ('prof3', 'Sexta_M3'): 1,
#   ('prof3', 'Sexta_M4'): 1,
#   ('prof3', 'Sexta_T1'): 1,
#   ('prof3', 'Sexta_T2'): 1,
#   ('prof3', 'Sexta_T3'): 1,
#   ('prof3', 'Sexta_T4'): 1,
#   ('prof4', 'Segunda_M1'): 1,
#   ('prof4', 'Segunda_M2'): 1,
#   ('prof4', 'Segunda_M3'): 1,
#   ('prof4', 'Segunda_M4'): 1,
#   ('prof4', 'Segunda_T1'): 1,
#   ('prof4', 'Segunda_T2'): 1,
#   ('prof4', 'Segunda_T3'): 1,
#   ('prof4', 'Segunda_T4'): 1,
#   ('prof4', 'Terça_M1'): 1,
#   ('prof4', 'Terça_M2'): 1,
#   ('prof4', 'Terça_M3'): 1,
#   ('prof4', 'Terça_M4'): 1,
#   ('prof4', 'Terça_T1'): 1,
#   ('prof4', 'Terça_T2'): 1,
#   ('prof4', 'Terça_T3'): 1,
#   ('prof4', 'Terça_T4'): 1,
#   ('prof4', 'Quarta_M1'): 1,
#   ('prof4', 'Quarta_M2'): 1,
#   ('prof4', 'Quarta_M3'): 1,
#   ('prof4', 'Quarta_M4'): 1,
#   ('prof4', 'Quarta_T1'): 1,
#   ('prof4', 'Quarta_T2'): 1,
#   ('prof4', 'Quarta_T3'): 1,
#   ('prof4', 'Quarta_T4'): 1,
#   ('prof4', 'Quinta_M1'): 1,
#   ('prof4', 'Quinta_M2'): 1,
#   ('prof4', 'Quinta_M3'): 1,
#   ('prof4', 'Quinta_M4'): 1,
#   ('prof4', 'Quinta_T1'): 1,
#   ('prof4', 'Quinta_T2'): 1,
#   ('prof4', 'Quinta_T3'): 1,
#   ('prof4', 'Quinta_T4'): 1,
#   ('prof4', 'Sexta_M1'): 1,
#   ('prof4', 'Sexta_M2'): 1,
#   ('prof4', 'Sexta_M3'): 1,
#   ('prof4', 'Sexta_M4'): 1,
#   ('prof4', 'Sexta_T1'): 1,
#   ('prof4', 'Sexta_T2'): 1,
#   ('prof4', 'Sexta_T3'): 1,
#   ('prof4', 'Sexta_T4'): 1,
#   ('prof5', 'Segunda_M1'): 1,
#   ('prof5', 'Segunda_M2'): 1,
#   ('prof5', 'Segunda_M3'): 1,
#   ('prof5', 'Segunda_M4'): 1,
#   ('prof5', 'Segunda_T1'): 1,
#   ('prof5', 'Segunda_T2'): 1,
#   ('prof5', 'Segunda_T3'): 1,
#   ('prof5', 'Segunda_T4'): 1,
#   ('prof5', 'Terça_M1'): 1,
#   ('prof5', 'Terça_M2'): 1,
#   ('prof5', 'Terça_M3'): 1,
#   ('prof5', 'Terça_M4'): 1,
#   ('prof5', 'Terça_T1'): 1,
#   ('prof5', 'Terça_T2'): 1,
#   ('prof5', 'Terça_T3'): 1,
#   ('prof5', 'Terça_T4'): 1,
#   ('prof5', 'Quarta_M1'): 1,
#   ('prof5', 'Quarta_M2'): 1,
#   ('prof5', 'Quarta_M3'): 1,
#   ('prof5', 'Quarta_M4'): 1,
#   ('prof5', 'Quarta_T1'): 1,
#   ('prof5', 'Quarta_T2'): 1,
#   ('prof5', 'Quarta_T3'): 1,
#   ('prof5', 'Quarta_T4'): 1,
#   ('prof5', 'Quinta_M1'): 1,
#   ('prof5', 'Quinta_M2'): 1,
#   ('prof5', 'Quinta_M3'): 1,
#   ('prof5', 'Quinta_M4'): 1,
#   ('prof5', 'Quinta_T1'): 1,
#   ('prof5', 'Quinta_T2'): 1,
#   ('prof5', 'Quinta_T3'): 1,
#   ('prof5', 'Quinta_T4'): 1,
#   ('prof5', 'Sexta_M1'): 1,
#   ('prof5', 'Sexta_M2'): 1,
#   ('prof5', 'Sexta_M3'): 1,
#   ('prof5', 'Sexta_M4'): 1,
#   ('prof5', 'Sexta_T1'): 1,
#   ('prof5', 'Sexta_T2'): 1,
#   ('prof5', 'Sexta_T3'): 1,
#   ('prof5', 'Sexta_T4'): 1,
#   ('prof6', 'Segunda_M1'): 1,
#   ('prof6', 'Segunda_M2'): 1,
#   ('prof6', 'Segunda_M3'): 1,
#   ('prof6', 'Segunda_M4'): 1,
#   ('prof6', 'Segunda_T1'): 1,
#   ('prof6', 'Segunda_T2'): 1,
#   ('prof6', 'Segunda_T3'): 1,
#   ('prof6', 'Segunda_T4'): 1,
#   ('prof6', 'Terça_M1'): 1,
#   ('prof6', 'Terça_M2'): 1,
#   ('prof6', 'Terça_M3'): 1,
#   ('prof6', 'Terça_M4'): 1,
#   ('prof6', 'Terça_T1'): 1,
#   ('prof6', 'Terça_T2'): 1,
#   ('prof6', 'Terça_T3'): 1,
#   ('prof6', 'Terça_T4'): 1,
#   ('prof6', 'Quarta_M1'): 1,
#   ('prof6', 'Quarta_M2'): 1,
#   ('prof6', 'Quarta_M3'): 1,
#   ('prof6', 'Quarta_M4'): 1,
#   ('prof6', 'Quarta_T1'): 1,
#   ('prof6', 'Quarta_T2'): 1,
#   ('prof6', 'Quarta_T3'): 1,
#   ('prof6', 'Quarta_T4'): 1,
#   ('prof6', 'Quinta_M1'): 1,
#   ('prof6', 'Quinta_M2'): 1,
#   ('prof6', 'Quinta_M3'): 1,
#   ('prof6', 'Quinta_M4'): 1,
#   ('prof6', 'Quinta_T1'): 1,
#   ('prof6', 'Quinta_T2'): 1,
#   ('prof6', 'Quinta_T3'): 1,
#   ('prof6', 'Quinta_T4'): 1,
#   ('prof6', 'Sexta_M1'): 1,
#   ('prof6', 'Sexta_M2'): 1,
#   ('prof6', 'Sexta_M3'): 1,
#   ('prof6', 'Sexta_M4'): 1,
#   ('prof6', 'Sexta_T1'): 1,
#   ('prof6', 'Sexta_T2'): 1,
#   ('prof6', 'Sexta_T3'): 1,
#   ('prof6', 'Sexta_T4'): 1,
#   ('prof7', 'Segunda_M1'): 1,
#   ('prof7', 'Segunda_M2'): 1,
#   ('prof7', 'Segunda_M3'): 1,
#   ('prof7', 'Segunda_M4'): 1,
#   ('prof7', 'Segunda_T1'): 1,
#   ('prof7', 'Segunda_T2'): 1,
#   ('prof7', 'Segunda_T3'): 1,
#   ('prof7', 'Segunda_T4'): 1,
#   ('prof7', 'Terça_M1'): 1,
#   ('prof7', 'Terça_M2'): 1,
#   ('prof7', 'Terça_M3'): 1,
#   ('prof7', 'Terça_M4'): 1,
#   ('prof7', 'Terça_T1'): 1,
#   ('prof7', 'Terça_T2'): 1,
#   ('prof7', 'Terça_T3'): 1,
#   ('prof7', 'Terça_T4'): 1,
#   ('prof7', 'Quarta_M1'): 1,
#   ('prof7', 'Quarta_M2'): 1,
#   ('prof7', 'Quarta_M3'): 1,
#   ('prof7', 'Quarta_M4'): 1,
#   ('prof7', 'Quarta_T1'): 1,
#   ('prof7', 'Quarta_T2'): 1,
#   ('prof7', 'Quarta_T3'): 1,
#   ('prof7', 'Quarta_T4'): 1,
#   ('prof7', 'Quinta_M1'): 1,
#   ('prof7', 'Quinta_M2'): 1,
#   ('prof7', 'Quinta_M3'): 1,
#   ('prof7', 'Quinta_M4'): 1,
#   ('prof7', 'Quinta_T1'): 1,
#   ('prof7', 'Quinta_T2'): 1,
#   ('prof7', 'Quinta_T3'): 1,
#   ('prof7', 'Quinta_T4'): 1,
#   ('prof7', 'Sexta_M1'): 1,
#   ('prof7', 'Sexta_M2'): 1,
#   ('prof7', 'Sexta_M3'): 1,
#   ('prof7', 'Sexta_M4'): 1,
#   ('prof7', 'Sexta_T1'): 1,
#   ('prof7', 'Sexta_T2'): 1,
#   ('prof7', 'Sexta_T3'): 1,
#   ('prof7', 'Sexta_T4'): 1,
#   ('prof8', 'Segunda_M1'): 1,
#   ('prof8', 'Segunda_M2'): 1,
#   ('prof8', 'Segunda_M3'): 1,
#   ('prof8', 'Segunda_M4'): 1,
#   ('prof8', 'Segunda_T1'): 1,
#   ('prof8', 'Segunda_T2'): 1,
#   ('prof8', 'Segunda_T3'): 1,
#   ('prof8', 'Segunda_T4'): 1,
#   ('prof8', 'Terça_M1'): 1,
#   ('prof8', 'Terça_M2'): 1,
#   ('prof8', 'Terça_M3'): 1,
#   ('prof8', 'Terça_M4'): 1,
#   ('prof8', 'Terça_T1'): 1,
#   ('prof8', 'Terça_T2'): 1,
#   ('prof8', 'Terça_T3'): 1,
#   ('prof8', 'Terça_T4'): 1,
#   ('prof8', 'Quarta_M1'): 1,
#   ('prof8', 'Quarta_M2'): 1,
#   ('prof8', 'Quarta_M3'): 1,
#   ('prof8', 'Quarta_M4'): 1,
#   ('prof8', 'Quarta_T1'): 1,
#   ('prof8', 'Quarta_T2'): 1,
#   ('prof8', 'Quarta_T3'): 1,
#   ('prof8', 'Quarta_T4'): 1,
#   ('prof8', 'Quinta_M1'): 1,
#   ('prof8', 'Quinta_M2'): 1,
#   ('prof8', 'Quinta_M3'): 1,
#   ('prof8', 'Quinta_M4'): 1,
#   ('prof8', 'Quinta_T1'): 1,
#   ('prof8', 'Quinta_T2'): 1,
#   ('prof8', 'Quinta_T3'): 1,
#   ('prof8', 'Quinta_T4'): 1,
#   ('prof8', 'Sexta_M1'): 1,
#   ('prof8', 'Sexta_M2'): 1,
#   ('prof8', 'Sexta_M3'): 1,
#   ('prof8', 'Sexta_M4'): 1,
#   ('prof8', 'Sexta_T1'): 1,
#   ('prof8', 'Sexta_T2'): 1,
#   ('prof8', 'Sexta_T3'): 1,
#   ('prof8', 'Sexta_T4'): 1,
#   ('prof9', 'Segunda_M1'): 1,
#   ('prof9', 'Segunda_M2'): 1,
#   ('prof9', 'Segunda_M3'): 1,
#   ('prof9', 'Segunda_M4'): 1,
#   ('prof9', 'Segunda_T1'): 1,
#   ('prof9', 'Segunda_T2'): 1,
#   ('prof9', 'Segunda_T3'): 1,
#   ('prof9', 'Segunda_T4'): 1,
#   ('prof9', 'Terça_M1'): 1,
#   ('prof9', 'Terça_M2'): 1,
#   ('prof9', 'Terça_M3'): 1,
#   ('prof9', 'Terça_M4'): 1,
#   ('prof9', 'Terça_T1'): 1,
#   ('prof9', 'Terça_T2'): 1,
#   ('prof9', 'Terça_T3'): 1,
#   ('prof9', 'Terça_T4'): 1,
#   ('prof9', 'Quarta_M1'): 1,
#   ('prof9', 'Quarta_M2'): 1,
#   ('prof9', 'Quarta_M3'): 1,
#   ('prof9', 'Quarta_M4'): 1,
#   ('prof9', 'Quarta_T1'): 1,
#   ('prof9', 'Quarta_T2'): 1,
#   ('prof9', 'Quarta_T3'): 1,
#   ('prof9', 'Quarta_T4'): 1,
#   ('prof9', 'Quinta_M1'): 1,
#   ('prof9', 'Quinta_M2'): 1,
#   ('prof9', 'Quinta_M3'): 1,
#   ('prof9', 'Quinta_M4'): 1,
#   ('prof9', 'Quinta_T1'): 1,
#   ('prof9', 'Quinta_T2'): 1,
#   ('prof9', 'Quinta_T3'): 1,
#   ('prof9', 'Quinta_T4'): 1,
#   ('prof9', 'Sexta_M1'): 1,
#   ('prof9', 'Sexta_M2'): 1,
#   ('prof9', 'Sexta_M3'): 1,
#   ('prof9', 'Sexta_M4'): 1,
#   ('prof9', 'Sexta_T1'): 1,
#   ('prof9', 'Sexta_T2'): 1,
#   ('prof9', 'Sexta_T3'): 1,
#   ('prof9', 'Sexta_T4'): 1,
#   ('prof10', 'Segunda_M1'): 1,
#   ('prof10', 'Segunda_M2'): 1,
#   ('prof10', 'Segunda_M3'): 1,
#   ('prof10', 'Segunda_M4'): 1,
#   ('prof10', 'Segunda_T1'): 1,
#   ('prof10', 'Segunda_T2'): 1,
#   ('prof10', 'Segunda_T3'): 1,
#   ('prof10', 'Segunda_T4'): 1,
#   ('prof10', 'Terça_M1'): 1,
#   ('prof10', 'Terça_M2'): 1,
#   ('prof10', 'Terça_M3'): 1,
#   ('prof10', 'Terça_M4'): 1,
#   ('prof10', 'Terça_T1'): 1,
#   ('prof10', 'Terça_T2'): 1,
#   ('prof10', 'Terça_T3'): 1,
#   ('prof10', 'Terça_T4'): 1,
#   ('prof10', 'Quarta_M1'): 1,
#   ('prof10', 'Quarta_M2'): 1,
#   ('prof10', 'Quarta_M3'): 1,
#   ('prof10', 'Quarta_M4'): 1,
#   ('prof10', 'Quarta_T1'): 1,
#   ('prof10', 'Quarta_T2'): 1,
#   ('prof10', 'Quarta_T3'): 1,
#   ('prof10', 'Quarta_T4'): 1,
#   ('prof10', 'Quinta_M1'): 1,
#   ('prof10', 'Quinta_M2'): 1,
#   ('prof10', 'Quinta_M3'): 1,
#   ('prof10', 'Quinta_M4'): 1,
#   ('prof10', 'Quinta_T1'): 1,
#   ('prof10', 'Quinta_T2'): 1,
#   ('prof10', 'Quinta_T3'): 1,
#   ('prof10', 'Quinta_T4'): 1,
#   ('prof10', 'Sexta_M1'): 1,
#   ('prof10', 'Sexta_M2'): 1,
#   ('prof10', 'Sexta_M3'): 1,
#   ('prof10', 'Sexta_M4'): 1,
#   ('prof10', 'Sexta_T1'): 1,
#   ('prof10', 'Sexta_T2'): 1,
#   ('prof10', 'Sexta_T3'): 1,
#   ('prof10', 'Sexta_T4'): 1,
#   ('prof11', 'Segunda_M1'): 1,
#   ('prof11', 'Segunda_M2'): 1,
#   ('prof11', 'Segunda_M3'): 1,
#   ('prof11', 'Segunda_M4'): 1,
#   ('prof11', 'Segunda_T1'): 1,
#   ('prof11', 'Segunda_T2'): 1,
#   ('prof11', 'Segunda_T3'): 1,
#   ('prof11', 'Segunda_T4'): 1,
#   ('prof11', 'Terça_M1'): 1,
#   ('prof11', 'Terça_M2'): 1,
#   ('prof11', 'Terça_M3'): 1,
#   ('prof11', 'Terça_M4'): 1,
#   ('prof11', 'Terça_T1'): 1,
#   ('prof11', 'Terça_T2'): 1,
#   ('prof11', 'Terça_T3'): 1,
#   ('prof11', 'Terça_T4'): 1,
#   ('prof11', 'Quarta_M1'): 1,
#   ('prof11', 'Quarta_M2'): 1,
#   ('prof11', 'Quarta_M3'): 1,
#   ('prof11', 'Quarta_M4'): 1,
#   ('prof11', 'Quarta_T1'): 1,
#   ('prof11', 'Quarta_T2'): 1,
#   ('prof11', 'Quarta_T3'): 1,
#   ('prof11', 'Quarta_T4'): 1,
#   ('prof11', 'Quinta_M1'): 1,
#   ('prof11', 'Quinta_M2'): 1,
#   ('prof11', 'Quinta_M3'): 1,
#   ('prof11', 'Quinta_M4'): 1,
#   ('prof11', 'Quinta_T1'): 1,
#   ('prof11', 'Quinta_T2'): 1,
#   ('prof11', 'Quinta_T3'): 1,
#   ('prof11', 'Quinta_T4'): 1,
#   ('prof11', 'Sexta_M1'): 1,
#   ('prof11', 'Sexta_M2'): 1,
#   ('prof11', 'Sexta_M3'): 1,
#   ('prof11', 'Sexta_M4'): 1,
#   ('prof11', 'Sexta_T1'): 1,
#   ('prof11', 'Sexta_T2'): 1,
#   ('prof11', 'Sexta_T3'): 1,
#   ('prof11', 'Sexta_T4'): 1,
#   ('prof12', 'Segunda_M1'): 1,
#   ('prof12', 'Segunda_M2'): 1,
#   ('prof12', 'Segunda_M3'): 1,
#   ('prof12', 'Segunda_M4'): 1,
#   ('prof12', 'Segunda_T1'): 1,
#   ('prof12', 'Segunda_T2'): 1,
#   ('prof12', 'Segunda_T3'): 1,
#   ('prof12', 'Segunda_T4'): 1,
#   ('prof12', 'Terça_M1'): 1,
#   ('prof12', 'Terça_M2'): 1,
#   ('prof12', 'Terça_M3'): 1,
#   ('prof12', 'Terça_M4'): 1,
#   ('prof12', 'Terça_T1'): 1,
#   ('prof12', 'Terça_T2'): 1,
#   ('prof12', 'Terça_T3'): 1,
#   ('prof12', 'Terça_T4'): 1,
#   ('prof12', 'Quarta_M1'): 1,
#   ('prof12', 'Quarta_M2'): 1,
#   ('prof12', 'Quarta_M3'): 1,
#   ('prof12', 'Quarta_M4'): 1,
#   ('prof12', 'Quarta_T1'): 1,
#   ('prof12', 'Quarta_T2'): 1,
#   ('prof12', 'Quarta_T3'): 1,
#   ('prof12', 'Quarta_T4'): 1,
#   ('prof12', 'Quinta_M1'): 1,
#   ('prof12', 'Quinta_M2'): 1,
#   ('prof12', 'Quinta_M3'): 1,
#   ('prof12', 'Quinta_M4'): 1,
#   ('prof12', 'Quinta_T1'): 1,
#   ('prof12', 'Quinta_T2'): 1,
#   ('prof12', 'Quinta_T3'): 1,
#   ('prof12', 'Quinta_T4'): 1,
#   ('prof12', 'Sexta_M1'): 1,
#   ('prof12', 'Sexta_M2'): 1,
#   ('prof12', 'Sexta_M3'): 1,
#   ('prof12', 'Sexta_M4'): 1,
#   ('prof12', 'Sexta_T1'): 1,
#   ('prof12', 'Sexta_T2'): 1,
#   ('prof12', 'Sexta_T3'): 1,
#   ('prof12', 'Sexta_T4'): 1,
#   ('prof_int1', 'Segunda_M1'): 0,
#   ('prof_int1', 'Segunda_M2'): 0,
#   ('prof_int1', 'Segunda_M3'): 0,
#   ('prof_int1', 'Segunda_M4'): 0,
#   ('prof_int1', 'Segunda_T1'): 1,
#   ('prof_int1', 'Segunda_T2'): 1,
#   ('prof_int1', 'Segunda_T3'): 1,
#   ('prof_int1', 'Segunda_T4'): 1,
#   ('prof_int1', 'Terça_M1'): 0,
#   ('prof_int1', 'Terça_M2'): 0,
#   ('prof_int1', 'Terça_M3'): 0,
#   ('prof_int1', 'Terça_M4'): 0,
#   ('prof_int1', 'Terça_T1'): 1,
#   ('prof_int1', 'Terça_T2'): 1,
#   ('prof_int1', 'Terça_T3'): 1,
#   ('prof_int1', 'Terça_T4'): 1,
#   ('prof_int1', 'Quarta_M1'): 0,
#   ('prof_int1', 'Quarta_M2'): 0,
#   ('prof_int1', 'Quarta_M3'): 0,
#   ('prof_int1', 'Quarta_M4'): 0,
#   ('prof_int1', 'Quarta_T1'): 1,
#   ('prof_int1', 'Quarta_T2'): 1,
#   ('prof_int1', 'Quarta_T3'): 1,
#   ('prof_int1', 'Quarta_T4'): 1,
#   ('prof_int1', 'Quinta_M1'): 0,
#   ('prof_int1', 'Quinta_M2'): 0,
#   ('prof_int1', 'Quinta_M3'): 0,
#   ('prof_int1', 'Quinta_M4'): 0,
#   ('prof_int1', 'Quinta_T1'): 1,
#   ('prof_int1', 'Quinta_T2'): 1,
#   ('prof_int1', 'Quinta_T3'): 1,
#   ('prof_int1', 'Quinta_T4'): 1,
#   ('prof_int1', 'Sexta_M1'): 0,
#   ('prof_int1', 'Sexta_M2'): 0,
#   ('prof_int1', 'Sexta_M3'): 0,
#   ('prof_int1', 'Sexta_M4'): 0,
#   ('prof_int1', 'Sexta_T1'): 1,
#   ('prof_int1', 'Sexta_T2'): 1,
#   ('prof_int1', 'Sexta_T3'): 1,
#   ('prof_int1', 'Sexta_T4'): 1,
#   ('prof_ext1', 'Segunda_M1'): 0,
#   ('prof_ext1', 'Segunda_M2'): 0,
#   ('prof_ext1', 'Segunda_M3'): 0,
#   ('prof_ext1', 'Segunda_M4'): 0,
#   ('prof_ext1', 'Segunda_T1'): 1,
#   ('prof_ext1', 'Segunda_T2'): 1,
#   ('prof_ext1', 'Segunda_T3'): 1,
#   ('prof_ext1', 'Segunda_T4'): 1,
#   ('prof_ext1', 'Terça_M1'): 0,
#   ('prof_ext1', 'Terça_M2'): 0,
#   ('prof_ext1', 'Terça_M3'): 0,
#   ('prof_ext1', 'Terça_M4'): 0,
#   ('prof_ext1', 'Terça_T1'): 1,
#   ('prof_ext1', 'Terça_T2'): 1,
#   ('prof_ext1', 'Terça_T3'): 1,
#   ('prof_ext1', 'Terça_T4'): 1,
#   ('prof_ext1', 'Quarta_M1'): 0,
#   ('prof_ext1', 'Quarta_M2'): 0,
#   ('prof_ext1', 'Quarta_M3'): 0,
#   ('prof_ext1', 'Quarta_M4'): 0,
#   ('prof_ext1', 'Quarta_T1'): 1,
#   ('prof_ext1', 'Quarta_T2'): 1,
#   ('prof_ext1', 'Quarta_T3'): 1,
#   ('prof_ext1', 'Quarta_T4'): 1,
#   ('prof_ext1', 'Quinta_M1'): 0,
#   ('prof_ext1', 'Quinta_M2'): 0,
#   ('prof_ext1', 'Quinta_M3'): 0,
#   ('prof_ext1', 'Quinta_M4'): 0,
#   ('prof_ext1', 'Quinta_T1'): 1,
#   ('prof_ext1', 'Quinta_T2'): 1,
#   ('prof_ext1', 'Quinta_T3'): 1,
#   ('prof_ext1', 'Quinta_T4'): 1,
#   ('prof_ext1', 'Sexta_M1'): 0,
#   ('prof_ext1', 'Sexta_M2'): 0,
#   ('prof_ext1', 'Sexta_M3'): 0,
#   ('prof_ext1', 'Sexta_M4'): 0,
#   ('prof_ext1', 'Sexta_T1'): 1,
#   ('prof_ext1', 'Sexta_T2'): 1,
#   ('prof_ext1', 'Sexta_T3'): 1,
#   ('prof_ext1', 'Sexta_T4'): 1,
#   ('prof_ext2', 'Segunda_M1'): 0,
#   ('prof_ext2', 'Segunda_M2'): 0,
#   ('prof_ext2', 'Segunda_M3'): 0,
#   ('prof_ext2', 'Segunda_M4'): 0,
#   ('prof_ext2', 'Segunda_T1'): 1,
#   ('prof_ext2', 'Segunda_T2'): 1,
#   ('prof_ext2', 'Segunda_T3'): 1,
#   ('prof_ext2', 'Segunda_T4'): 1,
#   ('prof_ext2', 'Terça_M1'): 0,
#   ('prof_ext2', 'Terça_M2'): 0,
#   ('prof_ext2', 'Terça_M3'): 0,
#   ('prof_ext2', 'Terça_M4'): 0,
#   ('prof_ext2', 'Terça_T1'): 1,
#   ('prof_ext2', 'Terça_T2'): 1,
#   ('prof_ext2', 'Terça_T3'): 1,
#   ('prof_ext2', 'Terça_T4'): 1,
#   ('prof_ext2', 'Quarta_M1'): 0,
#   ('prof_ext2', 'Quarta_M2'): 0,
#   ('prof_ext2', 'Quarta_M3'): 0,
#   ('prof_ext2', 'Quarta_M4'): 0,
#   ('prof_ext2', 'Quarta_T1'): 1,
#   ('prof_ext2', 'Quarta_T2'): 1,
#   ('prof_ext2', 'Quarta_T3'): 1,
#   ('prof_ext2', 'Quarta_T4'): 1,
#   ('prof_ext2', 'Quinta_M1'): 0,
#   ('prof_ext2', 'Quinta_M2'): 0,
#   ('prof_ext2', 'Quinta_M3'): 0,
#   ('prof_ext2', 'Quinta_M4'): 0,
#   ('prof_ext2', 'Quinta_T1'): 1,
#   ('prof_ext2', 'Quinta_T2'): 1,
#   ('prof_ext2', 'Quinta_T3'): 1,
#   ('prof_ext2', 'Quinta_T4'): 1,
#   ('prof_ext2', 'Sexta_M1'): 0,
#   ('prof_ext2', 'Sexta_M2'): 0,
#   ('prof_ext2', 'Sexta_M3'): 0,
#   ('prof_ext2', 'Sexta_M4'): 0,
#   ('prof_ext2', 'Sexta_T1'): 1,
#   ('prof_ext2', 'Sexta_T2'): 1,
#   ('prof_ext2', 'Sexta_T3'): 1,
#   ('prof_ext2', 'Sexta_T4'): 1,
#   ('prof_comp1', 'Segunda_M1'): 1,
#   ('prof_comp1', 'Segunda_M2'): 1,
#   ('prof_comp1', 'Segunda_M3'): 1,
#   ('prof_comp1', 'Segunda_M4'): 1,
#   ('prof_comp1', 'Segunda_T1'): 0,
#   ('prof_comp1', 'Segunda_T2'): 0,
#   ('prof_comp1', 'Segunda_T3'): 0,
#   ('prof_comp1', 'Segunda_T4'): 0,
#   ('prof_comp1', 'Terça_M1'): 1,
#   ('prof_comp1', 'Terça_M2'): 1,
#   ('prof_comp1', 'Terça_M3'): 1,
#   ('prof_comp1', 'Terça_M4'): 1,
#   ('prof_comp1', 'Terça_T1'): 0,
#   ('prof_comp1', 'Terça_T2'): 0,
#   ('prof_comp1', 'Terça_T3'): 0,
#   ('prof_comp1', 'Terça_T4'): 0,
#   ('prof_comp1', 'Quarta_M1'): 1,
#   ('prof_comp1', 'Quarta_M2'): 1,
#   ('prof_comp1', 'Quarta_M3'): 1,
#   ('prof_comp1', 'Quarta_M4'): 1,
#   ('prof_comp1', 'Quarta_T1'): 0,
#   ('prof_comp1', 'Quarta_T2'): 0,
#   ('prof_comp1', 'Quarta_T3'): 0,
#   ('prof_comp1', 'Quarta_T4'): 0,
#   ('prof_comp1', 'Quinta_M1'): 1,
#   ('prof_comp1', 'Quinta_M2'): 1,
#   ('prof_comp1', 'Quinta_M3'): 1,
#   ('prof_comp1', 'Quinta_M4'): 1,
#   ('prof_comp1', 'Quinta_T1'): 0,
#   ('prof_comp1', 'Quinta_T2'): 0,
#   ('prof_comp1', 'Quinta_T3'): 0,
#   ('prof_comp1', 'Quinta_T4'): 0,
#   ('prof_comp1', 'Sexta_M1'): 1,
#   ('prof_comp1', 'Sexta_M2'): 1,
#   ('prof_comp1', 'Sexta_M3'): 1,
#   ('prof_comp1', 'Sexta_M4'): 1,
#   ('prof_comp1', 'Sexta_T1'): 0,
#   ('prof_comp1', 'Sexta_T2'): 0,
#   ('prof_comp1', 'Sexta_T3'): 0,
#   ('prof_comp1', 'Sexta_T4'): 0,
#   ('prof_comp2', 'Segunda_M1'): 1,
#   ('prof_comp2', 'Segunda_M2'): 1,
#   ('prof_comp2', 'Segunda_M3'): 1,
#   ('prof_comp2', 'Segunda_M4'): 1,
#   ('prof_comp2', 'Segunda_T1'): 0,
#   ('prof_comp2', 'Segunda_T2'): 0,
#   ('prof_comp2', 'Segunda_T3'): 0,
#   ('prof_comp2', 'Segunda_T4'): 0,
#   ('prof_comp2', 'Terça_M1'): 1,
#   ('prof_comp2', 'Terça_M2'): 1,
#   ('prof_comp2', 'Terça_M3'): 1,
#   ('prof_comp2', 'Terça_M4'): 1,
#   ('prof_comp2', 'Terça_T1'): 0,
#   ('prof_comp2', 'Terça_T2'): 0,
#   ('prof_comp2', 'Terça_T3'): 0,
#   ('prof_comp2', 'Terça_T4'): 0,
#   ('prof_comp2', 'Quarta_M1'): 1,
#   ('prof_comp2', 'Quarta_M2'): 1,
#   ('prof_comp2', 'Quarta_M3'): 1,
#   ('prof_comp2', 'Quarta_M4'): 1,
#   ('prof_comp2', 'Quarta_T1'): 0,
#   ('prof_comp2', 'Quarta_T2'): 0,
#   ('prof_comp2', 'Quarta_T3'): 0,
#   ('prof_comp2', 'Quarta_T4'): 0,
#   ('prof_comp2', 'Quinta_M1'): 1,
#   ('prof_comp2', 'Quinta_M2'): 1,
#   ('prof_comp2', 'Quinta_M3'): 1,
#   ('prof_comp2', 'Quinta_M4'): 1,
#   ('prof_comp2', 'Quinta_T1'): 0,
#   ('prof_comp2', 'Quinta_T2'): 0,
#   ('prof_comp2', 'Quinta_T3'): 0,
#   ('prof_comp2', 'Quinta_T4'): 0,
#   ('prof_comp2', 'Sexta_M1'): 1,
#   ('prof_comp2', 'Sexta_M2'): 1,
#   ('prof_comp2', 'Sexta_M3'): 1,
#   ('prof_comp2', 'Sexta_M4'): 1,
#   ('prof_comp2', 'Sexta_T1'): 0,
#   ('prof_comp2', 'Sexta_T2'): 0,
#   ('prof_comp2', 'Sexta_T3'): 0,
#   ('prof_comp2', 'Sexta_T4'): 0},
#  'quantidade_aulas': {('1A', 'Arte'): 1,
#   ('1A', 'Biologia'): 2,
#   ('1A', 'Educacao Fisica'): 1,
#   ('1A', 'Filosofia'): 1,
#   ('1A', 'Fisica'): 2,
#   ('1A', 'Geografia'): 2,
#   ('1A', 'Historia'): 2,
#   ('1A', 'Lingua Inglesa'): 2,
#   ('1A', 'Portugues'): 4,
#   ('1A', 'Matematica'): 4,
#   ('1A', 'Quimica'): 2,
#   ('1A', 'Sociologia'): 1,
#   ('1B', 'Arte'): 1,
#   ('1B', 'Biologia'): 2,
#   ('1B', 'Educacao Fisica'): 1,
#   ('1B', 'Filosofia'): 1,
#   ('1B', 'Fisica'): 2,
#   ('1B', 'Geografia'): 2,
#   ('1B', 'Historia'): 2,
#   ('1B', 'Lingua Inglesa'): 2,
#   ('1B', 'Portugues'): 4,
#   ('1B', 'Matematica'): 4,
#   ('1B', 'Quimica'): 2,
#   ('1B', 'Sociologia'): 1,
#   ('1C', 'Arte'): 1,
#   ('1C', 'Biologia'): 2,
#   ('1C', 'Educacao Fisica'): 1,
#   ('1C', 'Filosofia'): 1,
#   ('1C', 'Fisica'): 2,
#   ('1C', 'Geografia'): 2,
#   ('1C', 'Historia'): 2,
#   ('1C', 'Lingua Inglesa'): 2,
#   ('1C', 'Portugues'): 4,
#   ('1C', 'Matematica'): 4,
#   ('1C', 'Quimica'): 2,
#   ('1C', 'Sociologia'): 1,
#   ('2A', 'Arte'): 1,
#   ('2A', 'Biologia'): 2,
#   ('2A', 'Educacao Fisica'): 1,
#   ('2A', 'Filosofia'): 1,
#   ('2A', 'Fisica'): 2,
#   ('2A', 'Geografia'): 2,
#   ('2A', 'Historia'): 2,
#   ('2A', 'Lingua Inglesa'): 2,
#   ('2A', 'Portugues'): 4,
#   ('2A', 'Matematica'): 4,
#   ('2A', 'Quimica'): 2,
#   ('2A', 'Sociologia'): 1,
#   ('2B', 'Arte'): 1,
#   ('2B', 'Biologia'): 2,
#   ('2B', 'Educacao Fisica'): 1,
#   ('2B', 'Filosofia'): 1,
#   ('2B', 'Fisica'): 2,
#   ('2B', 'Geografia'): 2,
#   ('2B', 'Historia'): 2,
#   ('2B', 'Lingua Inglesa'): 2,
#   ('2B', 'Portugues'): 4,
#   ('2B', 'Matematica'): 4,
#   ('2B', 'Quimica'): 2,
#   ('2B', 'Sociologia'): 1,
#   ('2C', 'Arte'): 1,
#   ('2C', 'Biologia'): 2,
#   ('2C', 'Educacao Fisica'): 1,
#   ('2C', 'Filosofia'): 1,
#   ('2C', 'Fisica'): 2,
#   ('2C', 'Geografia'): 2,
#   ('2C', 'Historia'): 2,
#   ('2C', 'Lingua Inglesa'): 2,
#   ('2C', 'Portugues'): 4,
#   ('2C', 'Matematica'): 4,
#   ('2C', 'Quimica'): 2,
#   ('2C', 'Sociologia'): 1,
#   ('3A', 'Arte'): 1,
#   ('3A', 'Biologia'): 2,
#   ('3A', 'Educacao Fisica'): 1,
#   ('3A', 'Filosofia'): 1,
#   ('3A', 'Fisica'): 2,
#   ('3A', 'Geografia'): 2,
#   ('3A', 'Historia'): 2,
#   ('3A', 'Lingua Inglesa'): 2,
#   ('3A', 'Portugues'): 5,
#   ('3A', 'Matematica'): 5,
#   ('3A', 'Quimica'): 2,
#   ('3A', 'Sociologia'): 1,
#   ('3B', 'Arte'): 1,
#   ('3B', 'Biologia'): 2,
#   ('3B', 'Educacao Fisica'): 1,
#   ('3B', 'Filosofia'): 1,
#   ('3B', 'Fisica'): 2,
#   ('3B', 'Geografia'): 2,
#   ('3B', 'Historia'): 2,
#   ('3B', 'Lingua Inglesa'): 2,
#   ('3B', 'Portugues'): 5,
#   ('3B', 'Matematica'): 5,
#   ('3B', 'Quimica'): 2,
#   ('3B', 'Sociologia'): 1,
#   ('3C', 'Arte'): 1,
#   ('3C', 'Biologia'): 2,
#   ('3C', 'Educacao Fisica'): 1,
#   ('3C', 'Filosofia'): 1,
#   ('3C', 'Fisica'): 2,
#   ('3C', 'Geografia'): 2,
#   ('3C', 'Historia'): 2,
#   ('3C', 'Lingua Inglesa'): 2,
#   ('3C', 'Portugues'): 5,
#   ('3C', 'Matematica'): 5,
#   ('3C', 'Quimica'): 2,
#   ('3C', 'Sociologia'): 1},
#  'disciplinas_complementares': ['Cultura digital', 'Estudo orientado'],
#  'disciplinas_itinerario_formativo': ['Senac', 'CESAR', 'Inovativa'],
#  'turma_sala': {'1A': 'Sala_1',
#   '1B': 'Sala_2',
#   '1C': 'Sala_3',
#   '2A': 'Sala_4',
#   '2B': 'Sala_5',
#   '2C': 'Sala_6',
#   '3A': 'Sala_7',
#   '3B': 'Sala_8',
#   '3C': 'Sala_9'},
#  'atribuicoes_fixas': {('1A', 'Senac', 'prof_ext1', 'Quarta_T1'),
#   ('1A', 'Senac', 'prof_ext1', 'Quinta_T1'),
#   ('1B', 'CESAR', 'prof_ext2', 'Quarta_T1'),
#   ('1B', 'CESAR', 'prof_ext2', 'Segunda_T1'),
#   ('2A', 'CESAR', 'prof_ext2', 'Quinta_T1'),
#   ('2A', 'CESAR', 'prof_ext2', 'Terça_T1')}}

# %%
solucao, tabela = construir_e_resolver_modelo(instancia)

print("Objetivos:", pulp.value(solucao.objective))
print("Restrições:", len(solucao.constraints))
print("Variáveis:", len(solucao.variables()))

if tabela.empty:
    print("Nenhuma atribuição encontrada — instância possivelmente inviável ou precisa de tempo maior.")
else:
    print("\nGrade encontrada:")
    print(tabela.to_string())
# Out:
# STATUS DO SOLVER: Optimal
# Objetivos: None
# Restrições: 1372
# Variáveis: 5221
#
# Grade encontrada:
#     turma        disciplina   professor     horario    sala   fixa
# 0      1A        Sociologia       prof7   Quarta_M1  Sala_1  False
# 1      1B            Fisica       prof2   Quarta_M1  Sala_2  False
# 2      1C    Lingua Inglesa       prof5   Quarta_M1  Sala_3  False
# 3      2A          Historia       prof9   Quarta_M1  Sala_4  False
# 4      2B         Portugues       prof4   Quarta_M1  Sala_5  False
# 5      2C          Biologia      prof11   Quarta_M1  Sala_6  False
# 6      3B         Geografia       prof8   Quarta_M1  Sala_8  False
# 7      3C        Matematica       prof1   Quarta_M1  Sala_9  False
# 8      1A              Arte      prof12   Quarta_M2  Sala_1  False
# 9      1C           Quimica       prof3   Quarta_M2  Sala_3  False
# 10     2B          Historia       prof9   Quarta_M2  Sala_5  False
# 11     2C    Lingua Inglesa       prof5   Quarta_M2  Sala_6  False
# 12     3A        Matematica       prof1   Quarta_M2  Sala_7  False
# 13     3B         Portugues       prof4   Quarta_M2  Sala_8  False
# 14     3C         Geografia       prof8   Quarta_M2  Sala_9  False
# 15     1A         Geografia       prof8   Quarta_M3  Sala_1  False
# 16     1B           Quimica       prof3   Quarta_M3  Sala_2  False
# 17     1C              Arte      prof12   Quarta_M3  Sala_3  False
# 18     2A        Matematica       prof1   Quarta_M3  Sala_4  False
# 19     2B        Sociologia       prof7   Quarta_M3  Sala_5  False
# 20     2C         Portugues       prof4   Quarta_M3  Sala_6  False
# 21     3A    Lingua Inglesa       prof5   Quarta_M3  Sala_7  False
# 22     3C            Fisica       prof2   Quarta_M3  Sala_9  False
# 23     1A         Portugues       prof4   Quarta_M4  Sala_1  False
# 24     1C         Geografia       prof8   Quarta_M4  Sala_3  False
# 25     2A              Arte      prof12   Quarta_M4  Sala_4  False
# 26     3A           Quimica       prof3   Quarta_M4  Sala_7  False
# 27     3B            Fisica       prof2   Quarta_M4  Sala_8  False
# 28     3C        Matematica       prof1   Quarta_M4  Sala_9  False
# 29     1A             Senac   prof_ext1   Quarta_T1  Sala_1   True
# 30     1A             Senac   prof_ext1   Quarta_T1  Sala_1  False
# 31     1B             CESAR   prof_ext2   Quarta_T1  Sala_2   True
# 32     1B             CESAR   prof_ext2   Quarta_T1  Sala_2  False
# 33     1C        Sociologia       prof7   Quarta_T1  Sala_3  False
# 34     2B           Quimica       prof3   Quarta_T1  Sala_5  False
# 35     2C          Biologia      prof11   Quarta_T1  Sala_6  False
# 36     3B        Matematica       prof1   Quarta_T1  Sala_8  False
# 37     3C         Portugues       prof4   Quarta_T1  Sala_9  False
# 38     1A    Lingua Inglesa       prof5   Quarta_T2  Sala_1  False
# 39     2A         Portugues       prof4   Quarta_T2  Sala_4  False
# 40     2C        Sociologia       prof7   Quarta_T2  Sala_6  False
# 41     3A         Geografia       prof8   Quarta_T2  Sala_7  False
# 42     3B        Matematica       prof1   Quarta_T2  Sala_8  False
# 43     3C          Historia       prof9   Quarta_T2  Sala_9  False
# 44     1A        Matematica       prof1   Quarta_T3  Sala_1  False
# 45     1C            Fisica       prof2   Quarta_T3  Sala_3  False
# 46     2A          Historia       prof9   Quarta_T3  Sala_4  False
# 47     2B         Inovativa   prof_int1   Quarta_T3  Sala_5  False
# 48     2C         Geografia       prof8   Quarta_T3  Sala_6  False
# 49     3A         Portugues       prof4   Quarta_T3  Sala_7  False
# 50     3B          Biologia      prof11   Quarta_T3  Sala_8  False
# 51     1A        Matematica       prof1   Quarta_T4  Sala_1  False
# 52     1B         Geografia       prof8   Quarta_T4  Sala_2  False
# 53     1C          Biologia      prof11   Quarta_T4  Sala_3  False
# 54     2A        Sociologia       prof7   Quarta_T4  Sala_4  False
# 55     3B         Portugues       prof4   Quarta_T4  Sala_8  False
# 56     3C    Lingua Inglesa       prof5   Quarta_T4  Sala_9  False
# 57     1B        Matematica       prof1   Quinta_M1  Sala_2  False
# 58     2A          Biologia      prof11   Quinta_M1  Sala_4  False
# 59     2C            Fisica       prof2   Quinta_M1  Sala_6  False
# 60     3A         Portugues       prof4   Quinta_M1  Sala_7  False
# 61     3B    Lingua Inglesa       prof5   Quinta_M1  Sala_8  False
# 62     3C           Quimica       prof3   Quinta_M1  Sala_9  False
# 63     1A        Matematica       prof1   Quinta_M2  Sala_1  False
# 64     1B          Biologia      prof11   Quinta_M2  Sala_2  False
# 65     1C    Lingua Inglesa       prof5   Quinta_M2  Sala_3  False
# 66     2B          Historia       prof9   Quinta_M2  Sala_5  False
# 67     2C           Quimica       prof3   Quinta_M2  Sala_6  False
# 68     3A            Fisica       prof2   Quinta_M2  Sala_7  False
# 69     3C         Portugues       prof4   Quinta_M2  Sala_9  False
# 70     1A         Portugues       prof4   Quinta_M3  Sala_1  False
# 71     1B         Filosofia       prof6   Quinta_M3  Sala_2  False
# 72     1C        Matematica       prof1   Quinta_M3  Sala_3  False
# 73     2A          Biologia      prof11   Quinta_M3  Sala_4  False
# 74     2C          Historia       prof9   Quinta_M3  Sala_6  False
# 75     3B    Lingua Inglesa       prof5   Quinta_M3  Sala_8  False
# 76     3C  Estudo orientado  prof_comp2   Quinta_M3  Sala_9  False
# 77     1A          Biologia      prof11   Quinta_M4  Sala_1  False
# 78     1B         Portugues       prof4   Quinta_M4  Sala_2  False
# 79     1C           Quimica       prof3   Quinta_M4  Sala_3  False
# 80     2A            Fisica       prof2   Quinta_M4  Sala_4  False
# 81     2B    Lingua Inglesa       prof5   Quinta_M4  Sala_5  False
# 82     3B  Estudo orientado  prof_comp2   Quinta_M4  Sala_8  False
# 83     3C        Matematica       prof1   Quinta_M4  Sala_9  False
# 84     1A             Senac   prof_ext1   Quinta_T1  Sala_1   True
# 85     1A             Senac   prof_ext1   Quinta_T1  Sala_1  False
# 86     1B   Educacao Fisica      prof10   Quinta_T1  Sala_2  False
# 87     1C         Inovativa   prof_int1   Quinta_T1  Sala_3  False
# 88     2A             CESAR   prof_ext2   Quinta_T1  Sala_4   True
# 89     2A             CESAR   prof_ext2   Quinta_T1  Sala_4  False
# 90     2B              Arte      prof12   Quinta_T1  Sala_5  False
# 91     2C         Filosofia       prof6   Quinta_T1  Sala_6  False
# 92     3A         Portugues       prof4   Quinta_T1  Sala_7  False
# 93     3B        Matematica       prof1   Quinta_T1  Sala_8  False
# 94     1A           Quimica       prof3   Quinta_T2  Sala_1  False
# 95     1B         Geografia       prof8   Quinta_T2  Sala_2  False
# 96     1C          Historia       prof9   Quinta_T2  Sala_3  False
# 97     2A         Portugues       prof4   Quinta_T2  Sala_4  False
# 98     2B         Inovativa   prof_int1   Quinta_T2  Sala_5  False
# 99     3A        Matematica       prof1   Quinta_T2  Sala_7  False
# 100    3B          Biologia      prof11   Quinta_T2  Sala_8  False
# 101    3C    Lingua Inglesa       prof5   Quinta_T2  Sala_9  False
# 102    1A   Educacao Fisica      prof10   Quinta_T3  Sala_1  False
# 103    1B            Fisica       prof2   Quinta_T3  Sala_2  False
# 104    2B          Biologia      prof11   Quinta_T3  Sala_5  False
# 105    2C         Inovativa   prof_int1   Quinta_T3  Sala_6  False
# 106    3A        Matematica       prof1   Quinta_T3  Sala_7  False
# 107    3B           Quimica       prof3   Quinta_T3  Sala_8  False
# 108    3C         Portugues       prof4   Quinta_T3  Sala_9  False
# 109    1A          Historia       prof9   Quinta_T4  Sala_1  False
# 110    2A        Matematica       prof1   Quinta_T4  Sala_4  False
# 111    2B    Lingua Inglesa       prof5   Quinta_T4  Sala_5  False
# 112    2C         Inovativa   prof_int1   Quinta_T4  Sala_6  False
# 113    3A         Portugues       prof4   Quinta_T4  Sala_7  False
# 114    3B              Arte      prof12   Quinta_T4  Sala_8  False
# 115    3C          Biologia      prof11   Quinta_T4  Sala_9  False
# 116    1B           Quimica       prof3  Segunda_M1  Sala_2  False
# 117    2B         Portugues       prof4  Segunda_M1  Sala_5  False
# 118    2C          Historia       prof9  Segunda_M1  Sala_6  False
# 119    3A        Matematica       prof1  Segunda_M1  Sala_7  False
# 120    3C         Geografia       prof8  Segunda_M1  Sala_9  False
# 121    1A    Lingua Inglesa       prof5  Segunda_M2  Sala_1  False
# 122    1B          Historia       prof9  Segunda_M2  Sala_2  False
# 123    1C          Biologia      prof11  Segunda_M2  Sala_3  False
# 124    2B   Educacao Fisica      prof10  Segunda_M2  Sala_5  False
# 125    2C         Portugues       prof4  Segunda_M2  Sala_6  False
# 126    3B        Matematica       prof1  Segunda_M2  Sala_8  False
# 127    3C            Fisica       prof2  Segunda_M2  Sala_9  False
# 128    1A         Geografia       prof8  Segunda_M3  Sala_1  False
# 129    2A         Portugues       prof4  Segunda_M3  Sala_4  False
# 130    2B            Fisica       prof2  Segunda_M3  Sala_5  False
# 131    2C        Matematica       prof1  Segunda_M3  Sala_6  False
# 132    3B          Historia       prof9  Segunda_M3  Sala_8  False
# 133    3C           Quimica       prof3  Segunda_M3  Sala_9  False
# 134    1A         Portugues       prof4  Segunda_M4  Sala_1  False
# 135    2A            Fisica       prof2  Segunda_M4  Sala_4  False
# 136    2B        Matematica       prof1  Segunda_M4  Sala_5  False
# 137    3A          Biologia      prof11  Segunda_M4  Sala_7  False
# 138    3B         Filosofia       prof6  Segunda_M4  Sala_8  False
# 139    3C   Educacao Fisica      prof10  Segunda_M4  Sala_9  False
# 140    1A          Historia       prof9  Segunda_T1  Sala_1  False
# 141    1B             CESAR   prof_ext2  Segunda_T1  Sala_2   True
# 142    1B             CESAR   prof_ext2  Segunda_T1  Sala_2  False
# 143    1C        Matematica       prof1  Segunda_T1  Sala_3  False
# 144    2B           Quimica       prof3  Segunda_T1  Sala_5  False
# 145    2C         Portugues       prof4  Segunda_T1  Sala_6  False
# 146    3A         Geografia       prof8  Segunda_T1  Sala_7  False
# 147    1A           Quimica       prof3  Segunda_T2  Sala_1  False
# 148    1C        Matematica       prof1  Segunda_T2  Sala_3  False
# 149    2A   Educacao Fisica      prof10  Segunda_T2  Sala_4  False
# 150    2B         Filosofia       prof6  Segunda_T2  Sala_5  False
# 151    2C            Fisica       prof2  Segunda_T2  Sala_6  False
# 152    3A              Arte      prof12  Segunda_T2  Sala_7  False
# 153    3B         Geografia       prof8  Segunda_T2  Sala_8  False
# 154    3C          Historia       prof9  Segunda_T2  Sala_9  False
# 155    1A         Filosofia       prof6  Segunda_T3  Sala_1  False
# 156    1B          Historia       prof9  Segunda_T3  Sala_2  False
# 157    2C        Matematica       prof1  Segunda_T3  Sala_6  False
# 158    3B         Portugues       prof4  Segunda_T3  Sala_8  False
# 159    3C              Arte      prof12  Segunda_T3  Sala_9  False
# 160    1A            Fisica       prof2  Segunda_T4  Sala_1  False
# 161    1B          Biologia      prof11  Segunda_T4  Sala_2  False
# 162    2A         Filosofia       prof6  Segunda_T4  Sala_4  False
# 163    2B        Matematica       prof1  Segunda_T4  Sala_5  False
# 164    2C         Geografia       prof8  Segunda_T4  Sala_6  False
# 165    3A        Sociologia       prof7  Segunda_T4  Sala_7  False
# 166    3B           Quimica       prof3  Segunda_T4  Sala_8  False
# 167    3C         Portugues       prof4  Segunda_T4  Sala_9  False
# 168    1B        Matematica       prof1    Sexta_M1  Sala_2  False
# 169    1C   Educacao Fisica      prof10    Sexta_M1  Sala_3  False
# 170    2A           Quimica       prof3    Sexta_M1  Sala_4  False
# 171    2B         Geografia       prof8    Sexta_M1  Sala_5  False
# 172    3A          Historia       prof9    Sexta_M1  Sala_7  False
# 173    3B         Portugues       prof4    Sexta_M1  Sala_8  False
# 174    3C   Cultura digital  prof_comp1    Sexta_M1  Sala_9  False
# 175    1C         Portugues       prof4    Sexta_M2  Sala_3  False
# 176    2B         Geografia       prof8    Sexta_M2  Sala_5  False
# 177    3A  Estudo orientado  prof_comp2    Sexta_M2  Sala_7  False
# 178    3B   Educacao Fisica      prof10    Sexta_M2  Sala_8  False
# 179    3C        Matematica       prof1    Sexta_M2  Sala_9  False
# 180    1B    Lingua Inglesa       prof5    Sexta_M3  Sala_2  False
# 181    1C          Historia       prof9    Sexta_M3  Sala_3  False
# 182    2B        Matematica       prof1    Sexta_M3  Sala_5  False
# 183    3A         Portugues       prof4    Sexta_M3  Sala_7  False
# 184    3B   Cultura digital  prof_comp1    Sexta_M3  Sala_8  False
# 185    3C         Filosofia       prof6    Sexta_M3  Sala_9  False
# 186    1B        Matematica       prof1    Sexta_M4  Sala_2  False
# 187    1C            Fisica       prof2    Sexta_M4  Sala_3  False
# 188    2A         Geografia       prof8    Sexta_M4  Sala_4  False
# 189    2B          Biologia      prof11    Sexta_M4  Sala_5  False
# 190    2C           Quimica       prof3    Sexta_M4  Sala_6  False
# 191    3A   Educacao Fisica      prof10    Sexta_M4  Sala_7  False
# 192    3B         Portugues       prof4    Sexta_M4  Sala_8  False
# 193    3C        Sociologia       prof7    Sexta_M4  Sala_9  False
# 194    1C         Portugues       prof4    Sexta_T1  Sala_3  False
# 195    2A        Matematica       prof1    Sexta_T1  Sala_4  False
# 196    2C    Lingua Inglesa       prof5    Sexta_T1  Sala_6  False
# 197    3A          Biologia      prof11    Sexta_T1  Sala_7  False
# 198    3B        Sociologia       prof7    Sexta_T1  Sala_8  False
# 199    1C         Inovativa   prof_int1    Sexta_T2  Sala_3  False
# 200    2A         Geografia       prof8    Sexta_T2  Sala_4  False
# 201    2C              Arte      prof12    Sexta_T2  Sala_6  False
# 202    3A         Filosofia       prof6    Sexta_T2  Sala_7  False
# 203    3B          Historia       prof9    Sexta_T2  Sala_8  False
# 204    3C         Portugues       prof4    Sexta_T2  Sala_9  False
# 205    1B         Portugues       prof4    Sexta_T3  Sala_2  False
# 206    2A        Matematica       prof1    Sexta_T3  Sala_4  False
# 207    3B            Fisica       prof2    Sexta_T3  Sala_8  False
# 208    1B         Portugues       prof4    Sexta_T4  Sala_2  False
# 209    2A    Lingua Inglesa       prof5    Sexta_T4  Sala_4  False
# 210    3A            Fisica       prof2    Sexta_T4  Sala_7  False
# 211    3C        Matematica       prof1    Sexta_T4  Sala_9  False
# 212    1B        Sociologia       prof7    Terça_M1  Sala_2  False
# 213    1C         Filosofia       prof6    Terça_M1  Sala_3  False
# 214    2A         Portugues       prof4    Terça_M1  Sala_4  False
# 215    3A        Matematica       prof1    Terça_M1  Sala_7  False
# 216    1B    Lingua Inglesa       prof5    Terça_M2  Sala_2  False
# 217    1C         Portugues       prof4    Terça_M2  Sala_3  False
# 218    2C        Matematica       prof1    Terça_M2  Sala_6  False
# 219    1C         Portugues       prof4    Terça_M3  Sala_3  False
# 220    2C        Matematica       prof1    Terça_M3  Sala_6  False
# 221    3A          Historia       prof9    Terça_M3  Sala_7  False
# 222    1A          Biologia      prof11    Terça_M4  Sala_1  False
# 223    2A    Lingua Inglesa       prof5    Terça_M4  Sala_4  False
# 224    2B         Portugues       prof4    Terça_M4  Sala_5  False
# 225    3A   Cultura digital  prof_comp1    Terça_M4  Sala_7  False
# 226    3B        Matematica       prof1    Terça_M4  Sala_8  False
# 227    1C        Matematica       prof1    Terça_T1  Sala_3  False
# 228    2A             CESAR   prof_ext2    Terça_T1  Sala_4   True
# 229    2A             CESAR   prof_ext2    Terça_T1  Sala_4  False
# 230    2B         Portugues       prof4    Terça_T1  Sala_5  False
# 231    3A           Quimica       prof3    Terça_T1  Sala_7  False
# 232    1A        Matematica       prof1    Terça_T2  Sala_1  False
# 233    1B         Portugues       prof4    Terça_T2  Sala_2  False
# 234    2A           Quimica       prof3    Terça_T2  Sala_4  False
# 235    2B            Fisica       prof2    Terça_T2  Sala_5  False
# 236    2C   Educacao Fisica      prof10    Terça_T2  Sala_6  False
# 237    3C          Biologia      prof11    Terça_T2  Sala_9  False
# 238    1A         Portugues       prof4    Terça_T3  Sala_1  False
# 239    1B              Arte      prof12    Terça_T3  Sala_2  False
# 240    2B        Matematica       prof1    Terça_T3  Sala_5  False
# 241    1A            Fisica       prof2    Terça_T4  Sala_1  False
# 242    1B        Matematica       prof1    Terça_T4  Sala_2  False
# 243    1C         Geografia       prof8    Terça_T4  Sala_3  False
# 244    2C         Portugues       prof4    Terça_T4  Sala_6  False
# 245    3A    Lingua Inglesa       prof5    Terça_T4  Sala_7  False

# %%
gerar_grade_horaria_por_turma(tabela, instancia, instancia["turmas"][3])
# Out:
#                                     Segunda                            Terça  \
# 8 às 9                                            Portugues - prof4 - Sala_4
# 9 às 10
# 10 às 11         Portugues - prof4 - Sala_4
# 11 às 12            Fisica - prof2 - Sala_4  Lingua Inglesa - prof5 - Sala_4
# 13 às 14                                          CESAR - prof_ext2 - Sala_4
# 14 às 15  Educacao Fisica - prof10 - Sala_4         Quimica - prof3 - Sala_4
# 15 às 16
# 16 às 17         Filosofia - prof6 - Sala_4
#
#                                Quarta                       Quinta  \
# 8 às 9      Historia - prof9 - Sala_4   Biologia - prof11 - Sala_4
# 9 às 10
# 10 às 11  Matematica - prof1 - Sala_4   Biologia - prof11 - Sala_4
# 11 às 12       Arte - prof12 - Sala_4      Fisica - prof2 - Sala_4
# 13 às 14                                CESAR - prof_ext2 - Sala_4
# 14 às 15   Portugues - prof4 - Sala_4   Portugues - prof4 - Sala_4
# 15 às 16    Historia - prof9 - Sala_4
# 16 às 17  Sociologia - prof7 - Sala_4  Matematica - prof1 - Sala_4
#
#                                     Sexta
# 8 às 9           Quimica - prof3 - Sala_4
# 9 às 10
# 10 às 11
# 11 às 12       Geografia - prof8 - Sala_4
# 13 às 14      Matematica - prof1 - Sala_4
# 14 às 15       Geografia - prof8 - Sala_4
# 15 às 16      Matematica - prof1 - Sala_4
# 16 às 17  Lingua Inglesa - prof5 - Sala_4

# %%
exportar_grades_para_excel(tabela, instancia, caminho_arquivo_excel="grade_horaria_padre_machado.xlsx", pasta="rascunhos")
# Out:
# Arquivo Excel gerado: grade_horaria_padre_machado.xlsx
